# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('q7.csv')

# %%
df
# Out:
#            country  sum(i.total) * 100 / (select sum(i.total) from invoice i)
# 0              USA                                          22.462424
# 1           Canada                                          13.053337
# 2           France                                           8.378425
# 3           Brazil                                           8.163704
# 4          Germany                                           6.719918
# 5   United Kingdom                                           4.846689
# 6   Czech Republic                                           3.875290
# 7         Portugal                                           3.317015
# 8            India                                           3.231985
# 9            Chile                                           2.002061
# 10         Ireland                                           1.959117
# 11         Hungary                                           1.959117
# ...

# %%
plt.pie(df.iloc[:,1],labels = df['country'], radius = 3, autopct="%1.1f%%");

# %%
df
# Out:
#            country  sum(i.total) * 100 / (select sum(i.total) from invoice i)
# 0              USA                                          22.462424
# 1           Canada                                          13.053337
# 2           France                                           8.378425
# 3           Brazil                                           8.163704
# 4          Germany                                           6.719918
# 5   United Kingdom                                           4.846689
# 6   Czech Republic                                           3.875290
# 7         Portugal                                           3.317015
# 8            India                                           3.231985
# 9            Chile                                           2.002061
# 10         Ireland                                           1.959117
# 11         Hungary                                           1.959117
# ...

# %%
df
# Out:
#            country  sum(i.total) * 100 / (select sum(i.total) from invoice i)
# 0              USA                                          22.462424
# 1           Canada                                          13.053337
# 2           France                                           8.378425
# 3           Brazil                                           8.163704
# 4          Germany                                           6.719918
# 5   United Kingdom                                           4.846689
# 6   Czech Republic                                           3.875290
# 7         Portugal                                           3.317015
# 8            India                                           3.231985
# 9            Chile                                           2.002061
# 10         Ireland                                           1.959117
# 11         Hungary                                           1.959117
# ...

# %%
slp = df.iloc[11:, 1].sum()

# %%
slp
# Out:
# 21.990036932062136

# %%
dff = df.iloc[:11,:11]

# %%
dff= dff.append({'country' : 'other', 'sum(i.total) * 100 / (select sum(i.total) from invoice i)' : slp},ignore_index=True)

# %%
plt.pie(dff.iloc[:,1],labels = dff['country'], radius = 3, autopct="%1.1f%%")
plt.title('Share of each country in Total Revenue Made In percentage', fontsize=20);
