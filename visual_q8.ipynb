# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('q8.csv')

# %%
df
df['Name'][4] = 'Os Paralamas...'
df
# Out:
# <ipython-input-84-e82f33bd20ef>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'][4] = 'Os Paralamas...'
#               Name  amtsold               Genre  cg  cnpg  cpg
# 0      Iron Maiden      140               Metal  70   118   95
# 1               U2      107                Rock  91    23  112
# 2        Metallica       91               Metal  91     0  112
# 3     Led Zeppelin       87                Rock  87     0  114
# 4  Os Paralamas...       45               Latin  45     0   49
# 5      Deep Purple       44                Rock  44     0   92
# 6    Faith No More       42  Alternative & Punk  33    15   37
# 7             Lost       41            TV Shows  23    44   48
# 8     Eric Clapton       40               Blues  27    16   32
# ...

# %%
df['Genre'][6] = 'Alternative \n& Punk'
df['Genre'][9] = 'Alternative \n& Punk'
# Out:
# <ipython-input-85-b5386bcf867e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Genre'][6] = 'Alternative \n& Punk'
# <ipython-input-85-b5386bcf867e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Genre'][9] = 'Alternative \n& Punk'

# %%
fig, ax = plt.subplots()
ser1 = np.arange(len(df['Name']))
plt.bar(ser1, df['amtsold'],0.5, label='Number of Tracks Sold For Artist')
barg = plt.bar(ser1, df['cg'],0.5, label='Number of Tracks Sold in Artist\'s most popular genre  ')
plt.bar(ser1+0.4, df['cnpg'], 0.1, label='Number of Tracks Released For Artist\'s Non Popular genre')
plt.bar(ser1+0.3, df['cpg'], 0.1,  label='Number of Tracks Released For Artist\'s Popular genre')
plt.xticks(ser1, df['Name'])

fig.set_size_inches(20,10)
plt.xlabel('Artist', fontsize= 15)
plt.ylabel('Number of Tracks Sold/Released', fontsize= 15)
plt.legend()
plt.title('Most Selling Artists & Their Most Selling Genres', fontsize=15)
for idx, rect in enumerate(barg):
    height = rect.get_height()
    width = rect.get_width()
    ratio = df['cg'][idx]/df['amtsold'][idx]
    text = df['Genre'][idx] +'\n' +str(round(ratio*100, 1)) + '%';
    ax.text(rect.get_x()+width/2, height/2.1,text, ha='center', fontsize = ratio*20, va='center', rotation =90)
